# %%
#pip install gensim
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = pd.read_csv('Datasets/Duolingo_en.csv')
#data = data[:1000]

# %%
data.head(10)
# Out:
#    Unnamed: 0                              reviewId  \
# 0           0  9330419d-eedc-424d-ae58-cb6eefc27e8a
# 1           1  a509f492-28f5-4d7a-b93d-7f9c9f8a0212
# 2           2  7361e2a5-b892-4b33-8eef-535dbc17c4c2
# 3           3  29b118a9-15b5-4dd1-af31-615d334cac93
# 4           4  546c745c-0a81-4530-82d6-61c63d300a2b
# 5           5  a6edb923-8296-4b90-8e94-fe9b93a93a3b
# 6           6  cbfdb368-ff1f-42f3-ad9b-7ac55253b32d
# 7           7  2661a134-2b3a-4c33-8d10-bd1b6d490e0e
# 8           8  c8ab2b6b-6140-47af-bb04-c0f4673d3266
# 9           9  b4c42cb0-ed6b-45f3-bf63-497cb931db1f
#
#                       userName  \
# 0                 Swiftie Suja
# 1                 Rashida Vera
# 2                  Emma Benson
# 3              Lucia Castañeda
# 4               Elliot Berluti
# 5             Ibrahim officiel
# 6                Pedro Fuentes
# 7                    Ann Bliss
# 8             saloomeh Sazegar
# 9  M̷i̷z̷z̷a̷d̷ D̷a̷r̷l̷i̷n̷g̷
#
# ...

# %%
data
# Out:
#       Unnamed: 0                              reviewId         userName  \
# 0              0  9330419d-eedc-424d-ae58-cb6eefc27e8a     Swiftie Suja
# 1              1  a509f492-28f5-4d7a-b93d-7f9c9f8a0212     Rashida Vera
# 2              2  7361e2a5-b892-4b33-8eef-535dbc17c4c2      Emma Benson
# 3              3  29b118a9-15b5-4dd1-af31-615d334cac93  Lucia Castañeda
# 4              4  546c745c-0a81-4530-82d6-61c63d300a2b   Elliot Berluti
# ...          ...                                   ...              ...
# 9995        9995  0b5e393c-97eb-4f02-b56f-0ea944c7d10e     SHEIKH RABBI
# 9996        9996  9533c8f3-90df-4f6b-81a9-8a79ba397869     Reena Kumari
# 9997        9997  5543bebb-9db1-432d-9fde-8685238936f2      Samrin Khan
# 9998        9998  49759cff-c8dd-4d3d-b384-213ae2f2c81d  Pritha Adhikary
# 9999        9999  d1d5066c-09bd-4e5b-845b-cb3eac7f12de    Julia Schenck
#
#                                               userImage  \
# ...

# %%
data = data[data['content'].str.len() > 30].reset_index()

# %%
data.head(10)
# Out:
#    index  Unnamed: 0                              reviewId          userName  \
# 0      0           0  9330419d-eedc-424d-ae58-cb6eefc27e8a      Swiftie Suja
# 1      1           1  a509f492-28f5-4d7a-b93d-7f9c9f8a0212      Rashida Vera
# 2      2           2  7361e2a5-b892-4b33-8eef-535dbc17c4c2       Emma Benson
# 3      3           3  29b118a9-15b5-4dd1-af31-615d334cac93   Lucia Castañeda
# 4      4           4  546c745c-0a81-4530-82d6-61c63d300a2b    Elliot Berluti
# 5      6           6  cbfdb368-ff1f-42f3-ad9b-7ac55253b32d     Pedro Fuentes
# 6      8           8  c8ab2b6b-6140-47af-bb04-c0f4673d3266  saloomeh Sazegar
# 7     12          12  b5d2c7bf-2b1d-468a-87f4-fae68bde2736  Jack Kirkpatrick
# 8     13          13  189cecfb-3431-4162-b91d-094418d79a49       farha fathy
# 9     14          14  36af41fc-a03b-4225-9c8d-7f5d01e979cd         Shintoism
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AD_cM...
# ...

# %%
data
# Out:
#       index  Unnamed: 0                              reviewId  \
# 0         0           0  9330419d-eedc-424d-ae58-cb6eefc27e8a
# 1         1           1  a509f492-28f5-4d7a-b93d-7f9c9f8a0212
# 2         2           2  7361e2a5-b892-4b33-8eef-535dbc17c4c2
# 3         3           3  29b118a9-15b5-4dd1-af31-615d334cac93
# 4         4           4  546c745c-0a81-4530-82d6-61c63d300a2b
# ...     ...         ...                                   ...
# 5467   9985        9985  594dc7b9-7279-4f83-925b-caa5ffcc0dc0
# 5468   9989        9989  ff0868df-5e97-446a-8dc0-4520b7dcaf1f
# 5469   9992        9992  4e1ec838-0270-411b-8539-80ea0f90f065
# 5470   9998        9998  49759cff-c8dd-4d3d-b384-213ae2f2c81d
# 5471   9999        9999  d1d5066c-09bd-4e5b-845b-cb3eac7f12de
#
#                        userName  \
# 0                  Swiftie Suja
# 1                  Rashida Vera
# 2                   Emma Benson
# 3               Lucia Castañeda
# 4                Elliot Berluti
# ...

# %%
reviews = data['content'].values

# %%
reviews
# Out:
# array(['I learned Spanish through this app. Thank you so much. I love it ❤',
#        'Excellent app! Would recommend to anyone wanting to learn a new language. Ive learned a lot in a short amount of time.',
#        "I've learned so much tbh love you duo❤️🤞🤞", ...,
#        'I used this app a while ago, so with that in mind, I LOVED it! I have never learned to use verbs well, in Spanish, but this ap makes it much easier to use and understand Spanish, as an English speaker. I am now able to use verbs. I like that the ap makes you speak the language, as well, because practicing speaking differnt sounds(rr, ñ, ll) is important for me to really absorb a language. Bravo!',
#        'This is a very nice app.....I like this 😌👍',
#        "I love learning with Duolingo, but since I'm learning this language in school too I'm better than how they thought I was. Basically I'm just revising not learning what I can't say in the language I'm learning"],
#       dtype=object)

# %%
import nltk
from gensim.models import Word2Vec, KeyedVectors

# %%
reviewsVec = [nltk.word_tokenize(comm) for comm in reviews]
model = Word2Vec(reviewsVec, min_count=1, vector_size=32)

# %%
model

# %%
# Get the vector for a specific word
vector = model.wv['word']
print(vector)
# Out:
# [ 0.12038235 -0.94705707  0.78592724  0.3787652   0.12895189 -0.40813592
#   0.7636378  -0.28934723 -0.77908766 -0.47392094  0.603163   -0.87763625
#   0.31602043 -0.5264225   0.01039611  0.13545802  0.26838556  0.49770716
#   0.00720118  1.3280056   0.8971583   1.0214872   1.7898754  -1.0630661
#   0.357918   -0.09329396 -0.9353471  -0.1703952  -0.02245405 -1.0134782
#  -0.38680887  0.07207362]

# %%
# Find similar words
similar_words = model.wv.most_similar('word')
print(similar_words)
# Out:
# [('out', 0.9985703229904175), ('They', 0.9984844326972961), ('back', 0.9984251856803894), ('-', 0.9983470439910889), ('complete', 0.9982172846794128), ('things', 0.9981565475463867), ('into', 0.9979670643806458), ('add', 0.9979614615440369), ('course', 0.9978872537612915), ('level', 0.9977947473526001)]

# %%
model.wv.most_similar('app')
# Out:
# [('application', 0.9916085600852966),
#  ('awesome', 0.9855751395225525),
#  ('helpful', 0.9851164221763611),
#  ('very', 0.9843406081199646),
#  ('game', 0.9837908744812012),
#  ('helping', 0.9836235642433167),
#  ('👍', 0.9827901124954224),
#  ('useful', 0.9825360178947449),
#  ('interesting', 0.9818885326385498),
#  ('Very', 0.9818525910377502)]

# %%
# Load a pre-trained Word2Vec model
model = Word2Vec.load("pretrained_word2vec.model")
