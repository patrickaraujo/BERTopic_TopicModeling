# %%
import pandas as pd

# %%
data0 = pd.read_csv('/home/patrick.araujo/topicModeling/export/export5_classe1.csv')

# %%
data0
# Out:
#       level_0  index       Time_submitted  \
# 0       51812  52074  2022-02-07 10:11:13
# 1       23185  23354  2022-05-06 01:42:00
# 2       44083  44336  2022-03-08 18:50:17
# 3       14403  14522  2022-06-02 00:23:46
# 4        2876   2894  2022-07-02 15:36:45
# ...       ...    ...                  ...
# 6746     1085   1091  2022-07-07 00:53:36
# 6747    44427  44681  2022-03-08 18:33:46
# 6748    20463  20611  2022-05-14 09:39:31
# 6749     2322   2335  2022-07-04 00:12:06
# 6750    19414  19556  2022-05-17 13:51:42
#
#                                                 content  score  \
# 0     The songs gets crack when the mobile gets off....      1
# 1     Convenient, however extremely buggy, especiall...      1
# 2     Something is very wrong. Kicked me out of my a...      1
# 3     Worst player ever. Does not play the song I ne...      1
# 4     Seems to use up a lot of processing, cause aud...      1
# ...                                                 ...    ...
# ...

# %%
data1 = pd.read_csv('/home/patrick.araujo/topicModeling/export/export5_classe2.csv')

# %%
data1
# Out:
#       level_0  index       Time_submitted  \
# 0       49179  49436  2022-02-17 07:33:36
# 1       28500  28715  2022-04-21 22:13:24
# 2       52312  52575  2022-02-05 18:33:22
# 3       37949  38188  2022-04-02 19:23:53
# 4       35541  35777  2022-04-12 02:28:45
# ...       ...    ...                  ...
# 6746    44611  44865  2022-03-08 18:22:49
# 6747    33264  33497  2022-04-14 12:52:12
# 6748    20490  20639  2022-05-14 07:39:02
# 6749    19371  19513  2022-05-17 16:17:19
# 6750    33465  33699  2022-04-14 07:44:07
#
#                                                 content  score  \
# 0     Songs stop playing for no reason. This is one ...      2
# 1     Problems with latest update. Ever since I upda...      2
# 2     Was a great app until they started caving to t...      2
# 3     Even you may get good music but worst experien...      2
# 4     Latest update broke spotify on my phone. No lo...      2
# ...                                                 ...    ...
# ...

# %%
data2 = pd.read_csv('/home/patrick.araujo/topicModeling/export/export5_classe3.csv')

# %%
data2
# Out:
#       level_0  index       Time_submitted  \
# 0       20230  20377  2022-05-15 02:48:31
# 1       15556  15685  2022-05-29 16:04:53
# 2       28360  28575  2022-04-22 05:34:56
# 3       53755  54021  2022-02-01 02:19:00
# 4       56065  56335  2022-01-25 03:18:10
# ...       ...    ...                  ...
# 6746    29110  29329  2022-04-21 00:54:35
# 6747    49442  49701  2022-02-16 07:15:36
# 6748    47879  48135  2022-02-22 12:56:00
# 6749    56046  56316  2022-01-25 05:09:19
# 6750    47446  47701  2022-02-24 05:39:11
#
#                                                 content  score  \
# 0     Why is the lyrics is not shown when i play the...      3
# 1     Really love the large collection of songs. Too...      3
# 2     It was great .. but the new version isn't show...      3
# 3     It's super laggy bc when I tried opening my 2n...      3
# 4     I love using Spotify but it goes thru tumes wh...      3
# ...                                                 ...    ...
# ...

# %%
data3 = pd.read_csv('/home/patrick.araujo/topicModeling/export/export5_classe4.csv')

# %%
data3
# Out:
#       level_0  index       Time_submitted  \
# 0       34086  34321  2022-04-13 16:40:13
# 1       58110  58382  2022-01-13 13:27:20
# 2       22705  22871  2022-05-07 10:19:15
# 3       57143  57415  2022-01-20 19:45:29
# 4       13621  13734  2022-06-04 11:24:04
# ...       ...    ...                  ...
# 6746     1354   1362  2022-07-06 10:30:48
# 6747     6946   7005  2022-06-22 12:40:20
# 6748    29036  29254  2022-04-21 03:36:32
# 6749    16686  16817  2022-05-26 10:58:34
# 6750    42797  43048  2022-03-12 06:06:03
#
#                                                 content  score  \
# 0     Something really frustrating that happens almo...      4
# 1     Spotify is awesome app for listening music but...      4
# 2     There r too many ads while listening online ot...      4
# 3     The app if very good and responsive, with crys...      4
# 4     It is a very nice music app but there are lots...      4
# ...                                                 ...    ...
# ...

# %%
data4 = pd.read_csv('/home/patrick.araujo/topicModeling/export/export5_classe5.csv')

# %%
data4
# Out:
#       level_0  index       Time_submitted  \
# 0       30989  31215  2022-04-17 22:10:35
# 1       21919  22078  2022-05-09 20:31:13
# 2       13757  13873  2022-06-04 01:37:47
# 3       45920  46174  2022-03-02 19:05:16
# 4       26038  26228  2022-04-27 18:02:12
# ...       ...    ...                  ...
# 6746    10203  10289  2022-06-14 08:16:36
# 6747    57028  57300  2022-01-21 09:17:12
# 6748    46788  47043  2022-02-27 02:10:43
# 6749     3548   3571  2022-06-30 21:59:43
# 6750    11046  11142  2022-06-12 02:55:25
#
#                                                 content  score  \
# 0     Very good app I've been able to listen to musi...      5
# 1     Unlimited music for a great price. What else d...      5
# 2     Just a wonderful app to use! Every band with a...      5
# 3     I've enjoyed the snippet of each song I needed...      5
# 4            I enjoy having my Spotify very convenient.      5
# ...                                                 ...    ...
# ...

# %%
merged_df = pd.concat([data0, data1, data2, data3, data4])
merged_df = merged_df.reset_index(drop=True)

# %%
merged_df
# Out:
#        level_0  index       Time_submitted  \
# 0        51812  52074  2022-02-07 10:11:13
# 1        23185  23354  2022-05-06 01:42:00
# 2        44083  44336  2022-03-08 18:50:17
# 3        14403  14522  2022-06-02 00:23:46
# 4         2876   2894  2022-07-02 15:36:45
# ...        ...    ...                  ...
# 33750    10203  10289  2022-06-14 08:16:36
# 33751    57028  57300  2022-01-21 09:17:12
# 33752    46788  47043  2022-02-27 02:10:43
# 33753     3548   3571  2022-06-30 21:59:43
# 33754    11046  11142  2022-06-12 02:55:25
#
#                                                  content  score  \
# 0      The songs gets crack when the mobile gets off....      1
# 1      Convenient, however extremely buggy, especiall...      1
# 2      Something is very wrong. Kicked me out of my a...      1
# 3      Worst player ever. Does not play the song I ne...      1
# 4      Seems to use up a lot of processing, cause aud...      1
# ...

# %%
shuffled_df = merged_df.sample(frac=1)

# %%
shuffled_df
# Out:
#        level_0  index       Time_submitted  \
# 30324    10217  10303  2022-06-14 07:13:43
# 12740    34296  34531  2022-04-13 12:42:01
# 28517    36344  36581  2022-04-10 13:33:03
# 14550    50895  51157  2022-02-10 14:53:04
# 32452    23543  23714  2022-05-05 00:42:42
# ...        ...    ...                  ...
# 8813     34297  34532  2022-04-13 12:35:46
# 2026     13529  13642  2022-06-04 16:56:35
# 26203    47686  47941  2022-02-23 07:18:31
# 31236    31435  31663  2022-04-17 01:08:43
# 18336     7757   7824  2022-06-20 14:14:28
#
#                                                  content  score  \
# 30324               Such a great app for wonderful music      5
# 12740  Stops and skips music randomly. App doesn't se...      2
# 28517  This is the best app ever in terms of new song...      5
# 14550  I'm just trying to listen to my playlist and i...      3
# 32452                    Favorite music app ..hands down      5
# ...

# %%
shuffled_df.to_csv('trainTesting/SpotifyAutoRU_DatasetRating5.csv', index=False)
