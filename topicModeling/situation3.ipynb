# %%
import pandas as pd

# %%
data0 = pd.read_csv('/home/patrick.araujo/topicModeling/out/export_outS_AmazonAutoRO_3_classe0.csv')

# %%
data0
# Out:
#       level_0    index  Unnamed: 0  reviewId        userName  \
# 0        5088   5300.0      7851.0     22790      Jason Gove
# 1          36     38.0        68.0     10348    Syra Charles
# 2       14916  15439.0     21750.0     16373         Frost F
# 3       11508  11921.0     17185.0      3686  Angel Quinones
# 4        3801   3946.0      5758.0     10683  Adrianna Hayes
# ...       ...      ...         ...       ...             ...
# 8019     5583   5823.0      8699.0      9626   Tory Anderson
# 8020      632    650.0       996.0     12759    louie hunton
# 8021     3018   3127.0      4520.0     20521      Noah McKee
# 8022     6501   6758.0      9947.0     22852   Carolyn White
# 8023    13929  14421.0     20401.0      1983   A Google user
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/ALV-U...
# 1     https://play-lh.googleusercontent.com/a-/ALV-U...
# 2     https://play-lh.googleusercontent.com/a-/ALV-U...
# ...

# %%
data1 = pd.read_csv('/home/patrick.araujo/topicModeling/out/export_outS_AmazonAutoRO_3_classe1.csv')

# %%
data1
# Out:
#       level_0    index  Unnamed: 0  reviewId           userName  \
# 0        1310   1352.0      2019.0      5971        Jake Harris
# 1       15764  16323.0     23164.0      7007   Zingisa Ndzamela
# 2       12670  13123.0     18716.0      6329  Richard L Youngll
# 3        1233      NaN         NaN     20121                NaN
# 4       16712  17300.0     24744.0     10446  bree marshallhibs
# ...       ...      ...         ...       ...                ...
# 8019     9897  10254.0     15167.0      4108            Steve C
# 8020    16546  17131.0     24477.0     18166              Nadia
# 8021     1360      NaN         NaN     22642                NaN
# 8022     8995   9307.0     13949.0     17772                P B
# 8023     3026      NaN         NaN      4921                NaN
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a/ACg8oc...
# 1     https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %%
data2 = pd.read_csv('/home/patrick.araujo/topicModeling/out/export_outS_AmazonAutoRO_3_classe2.csv')

# %%
data2
# Out:
#       level_0    index  Unnamed: 0  reviewId           userName  \
# 0        2653   2750.0      3992.0       663  Kym Cooks (PAPER)
# 1        7202   7466.0     10855.0     10376         Pat Mafull
# 2       15776  16335.0     23187.0       462     Roger Gauthier
# 3       13822  14311.0     20259.0     17290         Rudy Brown
# 4        2774      NaN         NaN     20031                NaN
# ...       ...      ...         ...       ...                ...
# 8019     1160      NaN         NaN     22505                NaN
# 8020      797      NaN         NaN     12474                NaN
# 8021     2181   2256.0      3304.0      2970         Robin Mize
# 8022     1203   1240.0      1856.0      9334      Wendy Douglas
# 8023     2468   2557.0      3720.0      5822         David Holt
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a/ACg8oc...
# 1     https://play-lh.googleusercontent.com/a-/ALV-U...
# ...

# %%
merged_df = pd.concat([data0, data1, data2])
merged_df = merged_df.reset_index(drop=True)

# %%
merged_df
# Out:
#        level_0    index  Unnamed: 0  reviewId        userName  \
# 0         5088   5300.0      7851.0     22790      Jason Gove
# 1           36     38.0        68.0     10348    Syra Charles
# 2        14916  15439.0     21750.0     16373         Frost F
# 3        11508  11921.0     17185.0      3686  Angel Quinones
# 4         3801   3946.0      5758.0     10683  Adrianna Hayes
# ...        ...      ...         ...       ...             ...
# 24067     1160      NaN         NaN     22505             NaN
# 24068      797      NaN         NaN     12474             NaN
# 24069     2181   2256.0      3304.0      2970      Robin Mize
# 24070     1203   1240.0      1856.0      9334   Wendy Douglas
# 24071     2468   2557.0      3720.0      5822      David Holt
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ALV-U...
# 1      https://play-lh.googleusercontent.com/a-/ALV-U...
# ...

# %%
shuffled_df = merged_df.sample(frac=1)

# %%
shuffled_df
# Out:
#        level_0    index  Unnamed: 0  reviewId             userName  \
# 20250     7339   7608.0     11121.0     17630          Donna Brown
# 3177     11432  11843.0     17077.0     17283           Rene Cesar
# 15711      240      NaN         NaN      9682                  NaN
# 4516     10173  10543.0     15523.0      3230        Michecoe Cole
# 6381      9327   9655.0     14390.0     13462           Aaron Lamb
# ...        ...      ...         ...       ...                  ...
# 305       4158   4322.0      6304.0      5955         Katie Barlow
# 15568    10313  10685.0     15697.0      9792               Kyle S
# 14622     3414      NaN         NaN     23376                  NaN
# 13944    16458  17039.0     24319.0     15523  Laurie KELSEY Myers
# 15510     3592      NaN         NaN     16383                  NaN
#
#                                                userImage  \
# 20250  https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %%
shuffled_df.to_csv('trainTesting/export_outS_AmazonAutoRO_3_classeALL.csv', index=False)
